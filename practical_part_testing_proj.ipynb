# %% [markdown]
# # Code for practical part of PDC Project

# %% [markdown]
# Hard limits to respect :
# - Codewords have to be in the space [-3/2, 3/2] x [-3/2, 3/2] -> **limits the energy per symbol**
# - The average energy of the vector **X** should be <= 1 -> **also limits the energy per symbol**
# - The dimension of the encoded vector **X** should not exceed n <= 100 -> **limits the number of symbols we can send**

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %% [markdown]
# ## Utility functions to help code the encoder/decoder

# %%
# Computes the value of the Q-Function
def q_function(x):
    return (1/2) * sp.erfc(x/np.sqrt(2))

# Gets every possible codeword lengths for which the length divides the total length of the original bitstring
def compute_codeword_lengths(bit_str):
    n = len(bit_str)
    return [i for i in range(1, n+1) if n % i == 0]

# Gets the whole alphabet from a codeword length
def get_alphabet_from_codeword_length(length):
    return [f'{i:0{length}b}' for i in range(0, 2**length)]

# Performs a conversion from ASCII string to binary symbols
def ascii_str_to_binary(ascii_str):
    return str(''.join(format(ord(i), '08b')[1:] for i in ascii_str))

# Performs the inverse conversion, from a binary stream to ASCII characters
def binary_to_ascii_str(binstr):
    byte_binstr = "".join([f"0{byte}" for byte in split_bit_str(binstr, 7)])
    binary_int = int(byte_binstr, 2)
    byte_number = binary_int.bit_length() + 7 // 8
    binary_array = binary_int.to_bytes(byte_number, "big")
    return binary_array.decode()

# Splits a bit string into chunks of size 'chunk_size'.
def split_bit_str(bit_str, chunk_size):
    return [bit_str[i:i+chunk_size] for i in range(0, len(bit_str), chunk_size)]

# Gets all the positions where bit_str1 is different from bit_str2 (bit_str1 and bit_str2 MUST HAVE THE SAME SIZE !)
def get_diff_positions(bit_str1, bit_str2):
    return [i for i in range(0, len(bit_str1)) if bit_str1[i] != bit_str2[i]]

# Computes the distance between a symbol and every point of a given constellation and returns the index of the nearest point in the constellation
def minimum_distance_criterion(constellation, symbol):
    return np.argmin([((symbol.real - point.real)**2 + (symbol.imag - point.imag)**2) for point in constellation])

# %% [markdown]
# ## Functions for the types of encodings

# %% [markdown]
# ### m-PSK

# %%
# Computes the probability of error for symbol i with PSK encoding (P_e(i) == P_e here !)
def error_m_psk(i, m, energy_per_symbol, noise_var = 10**(-2.65)):
    inner_part = lambda theta: np.exp(-(np.sin(np.pi/m)**2)**2 / np.sin(theta) * (energy_per_symbol/(2*(noise_var**2))))
    return (1/np.pi) * sp.quad(inner_part, 0, np.pi - (np.pi / m))

# Performs the m-PSK encoding
def m_psk_encoder(energy_per_symbol, codeword, alphabet, constellation = [], d=0):
    k = alphabet.index(codeword)
    m = len(alphabet)
    return np.sqrt(energy_per_symbol) * np.exp(2j * np.pi * (k/m))

# %% [markdown]
# ### QAM

# %%
# Computes the probability of error for symbol i with QAM encoding (P_e(i) == P_e here !)
def error_qam(m, d, noise_var = 10**(-2.65)):
    func = q_function(d/(2*noise_var))
    return 2*func - func**2

# Computes the PAM constellation for a given number of points and a distance for each of these points.
def pam(n, d):
    right_side = np.array([d*i + (d/2) for i in range(0, int(n/2))])
    left_side = -right_side
    return np.append(np.sort(left_side), right_side)


# Computes the whole m-QAM constellation, to be used to map each codeword to a point generated here
# WARNING: m MUST BE A POWER OF 2 HERE !!!
def m_qam(m, d, max_energy = (3/2)):
    if d > max_energy:
        raise OverflowError("ERROR: the distance you have set is too big for the project.")

    axis_len = int(np.sqrt(m))
    if axis_len % 2 != 0:
        axis_len = axis_len + 1

    diff_with_nearest_square = m - axis_len**2

    # if the difference is positive => we need to add some more points
    if diff_with_nearest_square > 0:
        real_axis_pam = pam(diff_with_nearest_square, d)
    else:
        real_axis_pam = pam(axis_len, d)
    if real_axis_pam.max() > max_energy:
        raise OverflowError("ERROR: You have some points that are outside the constrained square. Try to lower the distance or reduce the size of the constellation.")
    
    imaginary_axis_pam = pam(axis_len, d)[::-1]
    points_pairs = np.array([[complex(re, im) for re in real_axis_pam] for im in imaginary_axis_pam])

    # if the difference is negative => we need to remove some points from the constellation
    if diff_with_nearest_square < 0:
        nb_elts_to_delete_per_half_row = np.sqrt(-diff_with_nearest_square)/2
        nb_rows_to_modify = -diff_with_nearest_square / (2*nb_elts_to_delete_per_half_row)

        # First we set them to 0
        for j in range(0, int(nb_rows_to_modify/2)):
            for i in range(0, int(nb_elts_to_delete_per_half_row)):
                points_pairs[j, i] = 0
                points_pairs[j, len(points_pairs)-1-i] = 0
                points_pairs[len(points_pairs)-1-j, i] = 0
                points_pairs[len(points_pairs)-1-j, len(points_pairs)-1-i] = 0

    # We flatten the array to make it easier to map the codewords
    points_pairs = points_pairs.flatten()

    # Then, we remove all the points set to 0 (impossible to have if the dimension is a full square, so no worries)
    points_pairs = np.delete(points_pairs, np.argwhere(points_pairs == 0.0+0.0j))

    return points_pairs


# Performs the QAM encoding (in a linear fashion for the moment => might be re-worked)
def m_qam_encoder(codeword, constellation, alphabet, energy_per_symbol=0):
    try:
        k = alphabet.index(codeword)
        m = len(alphabet)
        return constellation[k]
    except OverflowError as ovferr:
        raise

# %% [markdown]
# ## Encoder part

# %%
# Encodes a string into a sequence of complex numbers & adds dummy points in front of it, given an encoder, a constellation, an alphabet and a number of dummy points
def encode_string(raw_str, n_dummy_symbols, encoder, dummy_symbol, constellation = [], alphabet = []):
    if n_dummy_symbols >= 100:
        raise OverflowError("ERROR: The batch of dummy samples cannot be equal or exceed 100 symbols.") 
    bit_str = ascii_str_to_binary(raw_str)
    splitted_bit_str = split_bit_str(bit_str, int(np.log2(len(alphabet))))
    splitted_bit_str_size = len(splitted_bit_str)
    if splitted_bit_str_size > 100:
        raise OverflowError("ERROR: The string without the dummy symbols cannot exceed 100 symbols.") 

    if splitted_bit_str_size + n_dummy_symbols > 100:
        raise OverflowError(f"ERROR: the number of dummy samples is too high, the max value you can set here is {100 - splitted_bit_str_size}.")
            
    theta_estimator_batch = np.full((n_dummy_symbols, 1), dummy_symbol)

    return np.append(theta_estimator_batch, np.array([encoder(codeword=codeword, constellation=constellation, alphabet=alphabet) for codeword in splitted_bit_str]))

# %% [markdown]
# ## Channel part (given)

# %%
def channel(sent_signal):
    s = np.mean(sent_signal**2)
    if s <= 1:
        s = 1
    noise_power = (10**(-2.65))*s
    shift = np.exp(-2j*np.pi*np.random.rand())
    print(f"Applied shift: {np.angle(shift)}")
    sent_signal = sent_signal*shift
    noise_std = np.sqrt(noise_power/2)
    rcv_signal = sent_signal + noise_std*np.random.randn(len(sent_signal)) + 1j*noise_std*np.random.randn(len(sent_signal))
    return rcv_signal

# %% [markdown]
# ## Decoder part

# %%
def decode_str(noisy_str, dummy_symbol, n_dummy_symbols, alphabet, constellation):
    # Isolate the dummy symbols to estimate the phase shift
    dummy_symbols = noisy_str[0:n_dummy_symbols]
    
    # Estimate the phase shift (np.angle gives a value between (-pi, pi])
    phase = (np.angle(np.sum(dummy_symbols)) + np.pi) - (np.angle(dummy_symbol) + np.pi) 

    print(f"Estimated phase: {phase}, phase with normalization: {phase % 2*np.pi}")
    # Apply the inverse phase shift to every codeword
    dephased_symbols = np.exp(-1j * phase) * noisy_str[n_dummy_symbols:]

    decoded_codewords = [alphabet[minimum_distance_criterion(constellation, symbol)] for symbol in dephased_symbols]
    resulting_bit_str = "".join(decoded_codewords)
    return resulting_bit_str

# %% [markdown]
# ## Putting everything together (for debugging)

# %%
str_to_process = "hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard"

# 78-chars ASCII string
encoder = m_qam_encoder

original_bitstr = ascii_str_to_binary(str_to_process)
n_dummy_symbols = 9
max_energy = 3/2

dummy_symbol = max_energy + 1j * max_energy

print(f"Performing an encoding/decoding on the string {str_to_process}:")
for codeword_size in compute_codeword_lengths(ascii_str_to_binary(str_to_process)):
    ideal_distances = []
    for d in np.arange(0.15, max_energy, 0.001):
        try:
            # We limit the size of codewords to avoid unrealistic constellations given our max-energy constraint
            if 2 <= codeword_size and codeword_size <= 10:
                print(f"For a {2**codeword_size}-QAM encoder with distance d = {d}:")
                constellation = m_qam(2**codeword_size, d)
                alphabet = get_alphabet_from_codeword_length(codeword_size)

                # We encode the string
                encoded_str = encode_string(str_to_process, constellation=constellation, alphabet=alphabet, n_dummy_symbols=n_dummy_symbols, dummy_symbol=dummy_symbol, encoder=encoder)

                # We pass it to the channel
                noisy_result = channel(encoded_str)

                # We decode it finally
                print("Decoded bit-string:")
                decoded_bitstr = decode_str(noisy_result, dummy_symbol=dummy_symbol, n_dummy_symbols=n_dummy_symbols, alphabet=alphabet, constellation=constellation)
                diff_positions = get_diff_positions(original_bitstr, decoded_bitstr)
                print(f"Number of differences (in bits from the original string): {len(diff_positions)} ->", diff_positions)

                print("Decoded ASCII string:")
                print(binary_to_ascii_str(decoded_bitstr))

                if len(diff_positions) == 0:
                    ideal_distances.append(d)      
        except OverflowError as ovferr:
            print(ovferr)
            print("--------------------")
            break # Go to another QAM configuration when we reach/go past the max-energy limit
        except UnicodeDecodeError as unicodeerr:
            print(unicodeerr)
            print()
            continue

    print(f"The ideal distances for a {2**codeword_size}-QAM are: {ideal_distances}")
# Out:
# Performing an encoding/decoding on the string hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard:
# The ideal distances for a 2-QAM are: []
# For a 4-QAM encoder with distance d = 0.15:
# ERROR: The string without the dummy symbols cannot exceed 100 symbols.
# --------------------
# The ideal distances for a 4-QAM are: []
# For a 8-QAM encoder with distance d = 0.15:
# ERROR: The string without the dummy symbols cannot exceed 100 symbols.
# --------------------
# The ideal distances for a 8-QAM are: []
# For a 64-QAM encoder with distance d = 0.15:
# Applied shift: -2.876116303948269
# Decoded bit-string:
# Estimated phase: -2.878617514549398, phase with normalization: 3.5229269781558745
# Number of differences (in bits from the original string): 15 -> [12, 13, 14, 101, 134, 138, 139, 140, 243, 244, 245, 332, 534, 535, 536]
# Decoded ASCII string:
# hf,lohowareyou|odayJ-tryingtodecodf4hestringlikmtheonegivenattheexambutitshand
# For a 64-QAM encoder with distance d = 0.151:
# Applied shift: 1.1214355604860897
# Decoded bit-string:
# Estimated phase: 1.122924218553755, phase with normalization: 3.5277704755465358
# Number of differences (in bits from the original string): 6 -> [47, 129, 130, 131, 323, 497]
# Decoded ASCII string:
# hellohmwareyoutodawimtryingtodecodethestringliKetheonegivenattheexambut)tshard
# For a 64-QAM encoder with distance d = 0.152:
# Applied shift: -1.2054774320019843
# Decoded bit-string:
# Estimated phase: -1.1984796728118363, phase with normalization: 2.5180503715972224
# Number of differences (in bits from the original string): 1 -> [2]
# Decoded ASCII string:
# xellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.153:
# Applied shift: -1.3283991977985299
# Decoded bit-string:
# Estimated phase: -1.3292748701616564, phase with normalization: 2.1071451404782007
# Number of differences (in bits from the original string): 3 -> [80, 85, 86]
# Decoded ASCII string:
# hellohowareq_utodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.154:
# Applied shift: 3.0513823072681205
# Decoded bit-string:
# Estimated phase: -3.2363820169580655, phase with normalization: 2.3989766456735966
# Number of differences (in bits from the original string): 2 -> [110, 449]
# Decoded ASCII string:
# hellohowareyoutmdayimtryingtodecodethestringliketheonegivenattheExambutitshard
# For a 64-QAM encoder with distance d = 0.155:
# Applied shift: -0.31109626761663556
# Decoded bit-string:
# Estimated phase: -0.3182951355285728, phase with normalization: 5.283231647729655
# Number of differences (in bits from the original string): 2 -> [137, 197]
# Decoded ASCII string:
# hellohowareyoutodaymmtryingtOdecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.156:
# Applied shift: -0.6645869264572755
# Decoded bit-string:
# Estimated phase: -0.658212195296715, phase with normalization: 4.215350709932216
# Number of differences (in bits from the original string): 8 -> [44, 151, 152, 302, 344, 426, 427, 428]
# Decoded ASCII string:
# hellohwareyoutodayimrryingtodecodethestrinGliketHeonegivenauheexambutitshard
# For a 64-QAM encoder with distance d = 0.157:
# Applied shift: -2.8275715008724864
# Decoded bit-string:
# Estimated phase: -2.826529097426357, phase with normalization: 3.6865675667267404
# Number of differences (in bits from the original string): 3 -> [23, 326, 410]
# Decoded ASCII string:
# hel|ohowareyoutodayimtryingtodecodethestringlioetheonegivejattheexambutitshard
# For a 64-QAM encoder with distance d = 0.158:
# Applied shift: -1.773259010564981
# Decoded bit-string:
# Estimated phase: -1.7714366017254828, phase with normalization: 0.7180530928987413
# Number of differences (in bits from the original string): 1 -> [428]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenatTheexambutitshard
# For a 64-QAM encoder with distance d = 0.159:
# Applied shift: 2.827117316629718
# Decoded bit-string:
# Estimated phase: -3.4675311221367346, phase with normalization: 1.6728003149604354
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.16:
# Applied shift: -2.1358403236461654
# Decoded bit-string:
# Estimated phase: -2.1397661304126734, phase with normalization: 5.844097058654459
# Number of differences (in bits from the original string): 2 -> [67, 68]
# Decoded ASCII string:
# hellohowateyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.161:
# Applied shift: 2.2830621021953887
# Decoded bit-string:
# Estimated phase: 2.277859095963655, phase with normalization: 0.8729200946125202
# Number of differences (in bits from the original string): 10 -> [212, 270, 271, 272, 513, 514, 515, 534, 535, 536]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtoducodethettringliketheonegivenattheexambutitohand
# For a 64-QAM encoder with distance d = 0.162:
# Applied shift: -2.6682927822334706
# Decoded bit-string:
# Estimated phase: -2.667961533905074, phase with normalization: 4.184722259382837
# Number of differences (in bits from the original string): 4 -> [18, 19, 20, 173]
# Decoded ASCII string:
# heklohowareyoutodayimtrykngtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.163:
# Applied shift: 2.3912494893175635
# Decoded bit-string:
# Estimated phase: -3.8905215128320974, phase with normalization: 0.3439368110128074
# Number of differences (in bits from the original string): 5 -> [73, 74, 124, 125, 353]
# Decoded ASCII string:
# hellohowariyoutodbyimtryingtodecodethestringlikethmonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.164:
# Applied shift: -2.8680790548367088
# Decoded bit-string:
# Estimated phase: -2.863495529507601, phase with normalization: 3.5704340952708793
# Number of differences (in bits from the original string): 3 -> [113, 430, 431]
# Decoded ASCII string:
# hellohowareyoutoDayimtryingtodecodethestringliketheonegivenatxheexambutitshard
# For a 64-QAM encoder with distance d = 0.165:
# Applied shift: 1.143679161136345
# Decoded bit-string:
# Estimated phase: 1.145827783649195, phase with normalization: 3.599724147391386
# Number of differences (in bits from the original string): 5 -> [104, 143, 330, 331, 332]
# Decoded ASCII string:
# hellohowareyouuodayietryingtodecodethestringlik]theonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.166:
# Applied shift: -2.534844178471373
# Decoded bit-string:
# Estimated phase: -2.5404615663966856, phase with normalization: 4.585275220640127
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.167:
# Applied shift: -3.0128254858514265
# Decoded bit-string:
# Estimated phase: -3.0104661123684515, phase with normalization: 3.1087123918614203
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.168:
# Applied shift: 1.6573392124883812
# Decoded bit-string:
# Estimated phase: 1.6577664882601644, phase with normalization: 5.208027020885482
# Number of differences (in bits from the original string): 1 -> [407]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegiveNattheexambutitshard
# For a 64-QAM encoder with distance d = 0.169:
# Applied shift: -3.038073685641775
# Decoded bit-string:
# Estimated phase: -3.0402625305808644, phase with normalization: 3.0151041833020154
# Number of differences (in bits from the original string): 7 -> [137, 160, 161, 224, 262, 263, 470]
# Decoded ASCII string:
# hellohowareyoutodaymmts9ingtodec/dethistringliketheonegivenattheexaMbutitshard
# For a 64-QAM encoder with distance d = 0.17:
# Applied shift: -1.7378435242676373
# Decoded bit-string:
# Estimated phase: -1.7403200536935097, phase with normalization: 0.8158086116010618
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.171:
# Applied shift: -0.29767107204429627
# Decoded bit-string:
# Estimated phase: -0.29823952738880877, phase with normalization: 5.346238198924813
# Number of differences (in bits from the original string): 1 -> [104]
# Decoded ASCII string:
# hellohowareyouuodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.17200000000000001:
# Applied shift: -1.7153368844314079
# Decoded bit-string:
# Estimated phase: -1.7157132631610064, phase with normalization: 0.8931131239663972
# Number of differences (in bits from the original string): 7 -> [323, 330, 331, 332, 349, 350, 416]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliK]ti%onegivenittheexambutitshard
# For a 64-QAM encoder with distance d = 0.17300000000000001:
# Applied shift: -0.4369033963210038
# Decoded bit-string:
# Estimated phase: -0.4323638032633941, phase with normalization: 4.924874359169165
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.17400000000000002:
# Applied shift: 1.7931675224246988
# Decoded bit-string:
# Estimated phase: 1.7945151223996616, phase with normalization: 5.637635525286565
# Number of differences (in bits from the original string): 6 -> [75, 76, 77, 204, 205, 206]
# Decoded ASCII string:
# hellohowarf9outodayimtryingto\ecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.17500000000000002:
# Applied shift: -0.024198062288362923
# Decoded bit-string:
# Estimated phase: -0.017806791924995125, phase with normalization: 6.227243620484019
# Number of differences (in bits from the original string): 1 -> [338]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringlikedheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.17600000000000002:
# Applied shift: -0.13850066863179264
# Decoded bit-string:
# Estimated phase: -0.14778640795333775, phase with normalization: 5.818900613652956
# Number of differences (in bits from the original string): 2 -> [526, 527]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshQrd
# For a 64-QAM encoder with distance d = 0.17700000000000002:
# Applied shift: 0.5626398613933914
# Decoded bit-string:
# Estimated phase: 0.5572721321045053, phase with normalization: 1.7507220362698346
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.17800000000000002:
# Applied shift: 2.8963255587817374
# Decoded bit-string:
# Estimated phase: -3.3965036229948273, phase with normalization: 1.8959397844675066
# Number of differences (in bits from the original string): 4 -> [122, 226, 227, 284]
# Decoded ASCII string:
# hellohowareyoutodiyimtryingtodecwdethestvingliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.17900000000000002:
# Applied shift: -2.755945674068904
# Decoded bit-string:
# Estimated phase: -2.7660327149469044, phase with normalization: 3.876622557492947
# Number of differences (in bits from the original string): 3 -> [381, 382, 383]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheoneiivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.18000000000000002:
# Applied shift: -2.2832153874881493
# Decoded bit-string:
# Estimated phase: -2.2872179105036032, phase with normalization: 5.3808636295620556
# Number of differences (in bits from the original string): 3 -> [6, 7, 8]
# Decoded ASCII string:
# illohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.18100000000000002:
# Applied shift: -1.0245450479585436
# Decoded bit-string:
# Estimated phase: -1.0262930147405367, phase with normalization: 3.058990711640195
# Number of differences (in bits from the original string): 2 -> [169, 170]
# Decoded ASCII string:
# hellohowareyoutodayimtryYngtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.18200000000000002:
# Applied shift: 0.3711988196091387
# Decoded bit-string:
# Estimated phase: 0.3690947820833381, phase with normalization: 1.1595454558713407
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.18300000000000002:
# Applied shift: -1.3737933474933142
# Decoded bit-string:
# Estimated phase: -1.3722337603856283, phase with normalization: 1.9721858065442
# Number of differences (in bits from the original string): 7 -> [125, 183, 184, 185, 232, 233, 272]
# Decoded ASCII string:
# hellohowareyoutod`yimtryin_todecoTethertringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.18400000000000002:
# Applied shift: -1.6093663313112312
# Decoded bit-string:
# Estimated phase: -1.6043911846039656, phase with normalization: 1.2428417481435423
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.18500000000000003:
# Applied shift: -1.5690836865560895
# Decoded bit-string:
# Estimated phase: -1.5831838200194865, phase with normalization: 1.309466648924142
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.18600000000000003:
# Applied shift: 1.1352045143012657
# Decoded bit-string:
# Estimated phase: 1.1247364010924974, phase with normalization: 3.533463614897213
# Number of differences (in bits from the original string): 2 -> [502, 503]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutjtshard
# For a 64-QAM encoder with distance d = 0.18700000000000003:
# Applied shift: -1.8959880229142703
# Decoded bit-string:
# Estimated phase: -1.9082442171905436, phase with normalization: 0.28825929319856886
# Number of differences (in bits from the original string): 4 -> [59, 258, 259, 260]
# Decoded ASCII string:
# hellohowireyoutodayimtryingtodecodetistringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.18800000000000003:
# Applied shift: 1.614036663139551
# Decoded bit-string:
# Estimated phase: 1.6045092138059847, phase with normalization: 5.040714358710016
# Number of differences (in bits from the original string): 3 -> [224, 449, 494]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodec/dethestringliketheonegivenattheExambupitshard
# For a 64-QAM encoder with distance d = 0.18900000000000003:
# Applied shift: -0.3343278875962434
# Decoded bit-string:
# Estimated phase: -0.3273174663271141, phase with normalization: 5.2548871595747
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.19000000000000003:
# Applied shift: 2.9833235428766924
# Decoded bit-string:
# Estimated phase: -3.2921206083206886, phase with normalization: 2.223868696527336
# Number of differences (in bits from the original string): 1 -> [434]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenatt(eexambutitshard
# For a 64-QAM encoder with distance d = 0.19100000000000003:
# Applied shift: 2.3018065215457204
# Decoded bit-string:
# Estimated phase: 2.3151228850126957, phase with normalization: 0.9899877405339059
# Number of differences (in bits from the original string): 2 -> [176, 461]
# Decoded ASCII string:
# hellohowareyoutodayimtryiNgtodecodethestringliketheonegivenattheeyambutitshard
# For a 64-QAM encoder with distance d = 0.19200000000000003:
# Applied shift: -1.0261276298444595
# Decoded bit-string:
# Estimated phase: -1.0194101751683053, phase with normalization: 3.080613789876154
# Number of differences (in bits from the original string): 4 -> [85, 86, 394, 395]
# Decoded ASCII string:
# hellohowarey_utodayimtryingtodecodethestringliketheoneginenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.19300000000000003:
# Applied shift: 2.979125345637225
# Decoded bit-string:
# Estimated phase: -3.2997842641250763, phase with normalization: 2.199792611752631
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.19400000000000003:
# Applied shift: 1.2389630415486776
# Decoded bit-string:
# Estimated phase: 1.2405183354326077, phase with normalization: 3.897203289238519
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.19500000000000003:
# Applied shift: -0.6571405149586428
# Decoded bit-string:
# Estimated phase: -0.6605511365103878, phase with normalization: 4.208002709398164
# Number of differences (in bits from the original string): 2 -> [52, 53]
# Decoded ASCII string:
# helloho{areyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.19600000000000004:
# Applied shift: -1.1158850622544632
# Decoded bit-string:
# Estimated phase: -1.1118439837482428, phase with normalization: 2.7902244158980976
# Number of differences (in bits from the original string): 2 -> [43, 44]
# Decoded ASCII string:
# helloh_wareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.19700000000000004:
# Applied shift: 0.6396471051536976
# Decoded bit-string:
# Estimated phase: 0.6374886093710872, phase with normalization: 2.002729531947381
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.19800000000000004:
# Applied shift: 2.197478698651653
# Decoded bit-string:
# Estimated phase: 2.197733522873685, phase with normalization: 0.6211981828283987
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.19900000000000004:
# Applied shift: 3.0978798847261686
# Decoded bit-string:
# Estimated phase: -3.1880078688940046, phase with normalization: 2.5509485138553156
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.20000000000000004:
# Applied shift: 1.9689223199055148
# Decoded bit-string:
# Estimated phase: 1.970164225644889, phase with normalization: 6.189453457651407
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.20100000000000004:
# Applied shift: -2.2213297997685415
# Decoded bit-string:
# Estimated phase: -2.2195642763176826, phase with normalization: 5.593403789709195
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.20200000000000004:
# Applied shift: 0.010546496317324983
# Decoded bit-string:
# Estimated phase: 0.008519397005248397, phase with normalization: 0.026764475044703247
# Number of differences (in bits from the original string): 1 -> [284]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestvingliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.20300000000000004:
# Applied shift: -2.713724150330299
# Decoded bit-string:
# Estimated phase: -2.7117917279460135, phase with normalization: 4.047025643778405
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.20400000000000004:
# Applied shift: 2.259814602921925
# Decoded bit-string:
# Estimated phase: 2.255217025193515, phase with normalization: 0.8017879314189874
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.20500000000000004:
# Applied shift: 0.8156840601036327
# Decoded bit-string:
# Estimated phase: 0.8223336474437133, phase with normalization: 2.5834373456088686
# Number of differences (in bits from the original string): 1 -> [314]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringmiketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.20600000000000004:
# Applied shift: 2.835737806815485
# Decoded bit-string:
# Estimated phase: -3.439305911431233, phase with normalization: 1.7614724295588626
# Number of differences (in bits from the original string): 1 -> [365]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheoNegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.20700000000000005:
# Applied shift: 2.6899569231181992
# Decoded bit-string:
# Estimated phase: -3.6015130465988463, phase with normalization: 1.2518836853564428
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.20800000000000005:
# Applied shift: 0.7402343331389133
# Decoded bit-string:
# Estimated phase: 0.7270900241870972, phase with normalization: 2.2842206784846097
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.20900000000000005:
# Applied shift: 2.435403825817026
# Decoded bit-string:
# Estimated phase: -3.8448555785818024, phase with normalization: 0.4874005745728486
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.21000000000000005:
# Applied shift: -2.653232472407321
# Decoded bit-string:
# Estimated phase: -2.650419220102806, phase with normalization: 4.239833063551008
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.21100000000000005:
# Applied shift: 0.6285573918445888
# Decoded bit-string:
# Estimated phase: 0.6282170288508162, phase with normalization: 1.9736020026977312
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.21200000000000005:
# Applied shift: 2.198115480756783
# Decoded bit-string:
# Estimated phase: 2.2085117264772043, phase with normalization: 0.6550589080881093
# Number of differences (in bits from the original string): 1 -> [23]
# Decoded ASCII string:
# hel|ohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.21300000000000005:
# Applied shift: -2.191555225018793
# Decoded bit-string:
# Estimated phase: -2.1912017923498066, phase with normalization: 5.682507160980233
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.21400000000000005:
# Applied shift: 1.786103979602408
# Decoded bit-string:
# Estimated phase: 1.7883758678008173, phase with normalization: 5.6183484881403185
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.21500000000000005:
# Applied shift: -2.3789857417308276
# Decoded bit-string:
# Estimated phase: -2.379610179462132, phase with normalization: 5.09060475615345
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.21600000000000005:
# Applied shift: 2.174069055244352
# Decoded bit-string:
# Estimated phase: 2.1756820142243134, phase with normalization: 0.5519213252549605
# Number of differences (in bits from the original string): 1 -> [254]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodetxestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.21700000000000005:
# Applied shift: 3.077819209024874
# Decoded bit-string:
# Estimated phase: -3.1988998888885116, phase with normalization: 2.516730223857819
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.21800000000000005:
# Applied shift: 2.9174535125865737
# Decoded bit-string:
# Estimated phase: -3.3613692630807646, phase with normalization: 2.006317631462106
# Number of differences (in bits from the original string): 1 -> [338]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringlikedheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.21900000000000006:
# Applied shift: -0.031786222331313965
# Decoded bit-string:
# Estimated phase: -0.034222114021339234, phase with normalization: 6.175673365179835
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.22000000000000006:
# Applied shift: -1.9753847534329885
# Decoded bit-string:
# Estimated phase: -1.974740744363788, phase with normalization: 0.07935429194186987
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.22100000000000006:
# Applied shift: -2.577472110063334
# Decoded bit-string:
# Estimated phase: -2.5675829343903027, phase with normalization: 4.500070930196074
# Number of differences (in bits from the original string): 1 -> [458]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheepambutitshard
# For a 64-QAM encoder with distance d = 0.22200000000000006:
# Applied shift: -1.3830165796539453
# Decoded bit-string:
# Estimated phase: -1.3871565736473803, phase with normalization: 1.9253044060301874
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.22300000000000006:
# Applied shift: -0.3843046751519006
# Decoded bit-string:
# Estimated phase: -0.38149634764300444, phase with normalization: 5.084679184052986
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.22400000000000006:
# Applied shift: 1.9501359012864585
# Decoded bit-string:
# Estimated phase: 1.9549937365316135, phase with normalization: 6.141793960501777
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.22500000000000006:
# Applied shift: 2.0150051796044184
# Decoded bit-string:
# Estimated phase: 2.0201417125743903, phase with normalization: 0.06327705625442187
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.22600000000000006:
# Applied shift: -0.41793604442992527
# Decoded bit-string:
# Estimated phase: -0.4148888465762206, phase with normalization: 4.979773554719388
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.22700000000000006:
# Applied shift: 0.39055275302145204
# Decoded bit-string:
# Estimated phase: 0.3917876109837666, phase with normalization: 1.230837080434097
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.22800000000000006:
# Applied shift: 2.402238986906609
# Decoded bit-string:
# Estimated phase: -3.870554529819459, phase with normalization: 0.40666493815966487
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.22900000000000006:
# Applied shift: 2.774977265815972
# Decoded bit-string:
# Estimated phase: -3.5066805511390275, phase with normalization: 1.5498087564145966
# Number of differences (in bits from the original string): 3 -> [138, 139, 140]
# Decoded ASCII string:
# hellohowareyoutodayj-tryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.23000000000000007:
# Applied shift: 0.037594621292891504
# Decoded bit-string:
# Estimated phase: 0.047242619693792065, phase with normalization: 0.14841706696635362
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.23100000000000007:
# Applied shift: -1.5449244002199223
# Decoded bit-string:
# Estimated phase: -1.5476142341074173, phase with normalization: 1.4212117987167299
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.23200000000000007:
# Applied shift: 1.532867340929369
# Decoded bit-string:
# Estimated phase: 1.5250710870492368, phase with normalization: 4.791152123276082
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.23300000000000007:
# Applied shift: -1.5195347157819525
# Decoded bit-string:
# Estimated phase: -1.5218175278077695, phase with normalization: 1.502254541714517
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.23400000000000007:
# Applied shift: 0.057352505405338115
# Decoded bit-string:
# Estimated phase: 0.05769523925240794, phase with normalization: 0.18125493978247023
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.23500000000000007:
# Applied shift: -0.9189920824895392
# Decoded bit-string:
# Estimated phase: -0.9171187441636466, phase with normalization: 3.4019717980455773
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.23600000000000007:
# Applied shift: -2.279848701182083
# Decoded bit-string:
# Estimated phase: -2.2787744440434774, phase with normalization: 5.407389561764019
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.23700000000000007:
# Applied shift: -2.0275301427487986
# Decoded bit-string:
# Estimated phase: -2.0295927123439577, phase with normalization: 6.1902170594800126
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.23800000000000007:
# Applied shift: -2.0271516525924076
# Decoded bit-string:
# Estimated phase: -2.0253368744307876, phase with normalization: 6.203587168602897
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.23900000000000007:
# Applied shift: -0.998097151345664
# Decoded bit-string:
# Estimated phase: -1.0024450382219627, phase with normalization: 3.133911339473929
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.24000000000000007:
# Applied shift: 0.20422640515785975
# Decoded bit-string:
# Estimated phase: 0.20372277109998205, phase with normalization: 0.6400139610566586
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.24100000000000008:
# Applied shift: 1.9991774506776212
# Decoded bit-string:
# Estimated phase: 2.003071716704567, phase with normalization: 0.009650082632976967
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.24200000000000008:
# Applied shift: 0.6624726322691069
# Decoded bit-string:
# Estimated phase: 0.6581094002537258, phase with normalization: 2.0675116570954897
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.24300000000000008:
# Applied shift: 2.7433356178642176
# Decoded bit-string:
# Estimated phase: -3.5430421577841464, phase with normalization: 1.4355754001055694
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.24400000000000008:
# Applied shift: 1.6924584351365983
# Decoded bit-string:
# Estimated phase: 1.6990306260843928, phase with normalization: 5.337662133130795
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.24500000000000008:
# Applied shift: -0.9050712832089676
# Decoded bit-string:
# Estimated phase: -0.9126243050130078, phase with normalization: 3.41609149506323
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.24600000000000008:
# Applied shift: -1.19950315787785
# Decoded bit-string:
# Estimated phase: -1.1995753693006415, phase with normalization: 2.514608139557428
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.24700000000000008:
# Applied shift: -2.573201566444423
# Decoded bit-string:
# Estimated phase: -2.5733750511022686, phase with normalization: 4.481874458885027
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.24800000000000008:
# Applied shift: 0.11336978251755639
# Decoded bit-string:
# Estimated phase: 0.11210280908822945, phase with normalization: 0.3521813614783607
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.24900000000000008:
# Applied shift: 2.7486045876742504
# Decoded bit-string:
# Estimated phase: -3.529199710305451, phase with normalization: 1.4790627314123412
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2500000000000001:
# Applied shift: 0.48414748267852237
# Decoded bit-string:
# Estimated phase: 0.48418366630409704, phase with normalization: 1.5211078490491232
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2510000000000001:
# Applied shift: -0.4150600683596393
# Decoded bit-string:
# Estimated phase: -0.41502321000355646, phase with normalization: 4.9793514395631595
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2520000000000001:
# Applied shift: 0.15588076146503863
# Decoded bit-string:
# Estimated phase: 0.15809368532723855, phase with normalization: 0.4966659604029891
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2530000000000001:
# Applied shift: -1.1930212076735376
# Decoded bit-string:
# Estimated phase: -1.191590337976447, phase with normalization: 2.539693855304202
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2540000000000001:
# Applied shift: 0.9779400689067911
# Decoded bit-string:
# Estimated phase: 0.9826329197053765, phase with normalization: 3.0870323617218998
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2550000000000001:
# Applied shift: 1.9344645126046525
# Decoded bit-string:
# Estimated phase: 1.9364663331178615, phase with normalization: 6.083588406047039
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2560000000000001:
# Applied shift: 1.9006393715148209
# Decoded bit-string:
# Estimated phase: 1.8879579644988764, phase with normalization: 5.931194871556009
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2570000000000001:
# Applied shift: -2.608987065255556
# Decoded bit-string:
# Estimated phase: -2.613427331319862, phase with normalization: 4.356046509593916
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2580000000000001:
# Applied shift: 1.9536804021075735
# Decoded bit-string:
# Estimated phase: 1.9553749129939169, phase with normalization: 6.14299146167547
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2590000000000001:
# Applied shift: -3.0569245941503014
# Decoded bit-string:
# Estimated phase: -3.0552202372643826, phase with normalization: 2.9681131618705234
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2600000000000001:
# Applied shift: 1.3133972778254057
# Decoded bit-string:
# Estimated phase: 1.3142920603120878, phase with normalization: 4.128970281347848
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2610000000000001:
# Applied shift: -1.9330679486758828
# Decoded bit-string:
# Estimated phase: -1.9345187213236599, phase with normalization: 0.2057155040372561
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2620000000000001:
# Applied shift: 2.9369430915923744
# Decoded bit-string:
# Estimated phase: -3.3450184065858704, phase with normalization: 2.0576853621063664
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2630000000000001:
# Applied shift: -2.625250061736647
# Decoded bit-string:
# Estimated phase: -2.621304370290706, phase with normalization: 4.3313000618310715
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2640000000000001:
# Applied shift: -1.1432959495442996
# Decoded bit-string:
# Estimated phase: -1.145806336727036, phase with normalization: 2.6835285372812976
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2650000000000001:
# Applied shift: -2.6096470658219686
# Decoded bit-string:
# Estimated phase: -2.607635716747512, phase with normalization: 4.374241403386834
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2660000000000001:
# Applied shift: 2.1099800613612962
# Decoded bit-string:
# Estimated phase: 2.113207847853923, phase with normalization: 0.3556529431465959
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2670000000000001:
# Applied shift: -1.2383224471906624
# Decoded bit-string:
# Estimated phase: -1.2549535896835153, phase with normalization: 2.340632329233715
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.2680000000000001:
# Applied shift: -0.6267058474409906
# Decoded bit-string:
# Estimated phase: -0.6162520010957397, phase with normalization: 4.347172547777201
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.26900000000000013:
# Applied shift: 1.973095544838934
# Decoded bit-string:
# Estimated phase: 1.9758429766493641, phase with normalization: 6.207293780088632
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.27000000000000013:
# Applied shift: 2.320725045087702
# Decoded bit-string:
# Estimated phase: 2.322811446976443, phase with normalization: 1.0141420703158848
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.27100000000000013:
# Applied shift: 0.23483353401565957
# Decoded bit-string:
# Estimated phase: 0.23570219502458212, phase with normalization: 0.7404802843242159
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.27200000000000013:
# Applied shift: 2.579909939581763
# Decoded bit-string:
# Estimated phase: -3.6980347953921178, phase with normalization: 0.9486516684358616
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.27300000000000013:
# Applied shift: -2.191656836456183
# Decoded bit-string:
# Estimated phase: -2.193192533747479, phase with normalization: 5.676253062430108
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.27400000000000013:
# Applied shift: -2.716739786184729
# Decoded bit-string:
# Estimated phase: -2.715257963816023, phase with normalization: 4.036136142633575
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.27500000000000013:
# Applied shift: 2.2183634447181695
# Decoded bit-string:
# Estimated phase: 2.217315723083235, phase with normalization: 0.6827174791478455
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.27600000000000013:
# Applied shift: 2.2945101596352857
# Decoded bit-string:
# Estimated phase: 2.291690775363656, phase with normalization: 0.9163735970023722
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.27700000000000014:
# Applied shift: 2.0749263686729233
# Decoded bit-string:
# Estimated phase: 2.0799059648779235, phase with normalization: 0.2510319922384883
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.27800000000000014:
# Applied shift: -1.4520940965607543
# Decoded bit-string:
# Estimated phase: -1.4597236124351407, phase with normalization: 1.6973283300817938
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 64-QAM encoder with distance d = 0.27900000000000014:
# Applied shift: -0.83766850873108
# Decoded bit-string:
# Estimated phase: -0.8423577270612439, phase with normalization: 3.6368404601493864
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# ...
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.23700000000000007:
# Applied shift: -2.1654113978685734
# Decoded bit-string:
# Estimated phase: -2.1608290697238974, phase with normalization: 5.777925883251309
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.23800000000000007:
# Applied shift: -2.574607100236106
# Decoded bit-string:
# Estimated phase: -2.577818897878159, phase with normalization: 4.467913702500211
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.23900000000000007:
# Applied shift: 1.3830454690574918
# Decoded bit-string:
# Estimated phase: 1.3891791848675021, phase with normalization: 4.364235121699601
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.24000000000000007:
# Applied shift: -2.0730670227933596
# Decoded bit-string:
# Estimated phase: -2.0727398982488205, phase with normalization: 6.054666177218222
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.24100000000000008:
# Applied shift: -2.1353828590867905
# Decoded bit-string:
# Estimated phase: -2.1425462417649546, phase with normalization: 5.835363081253971
# Number of differences (in bits from the original string): 2 -> [227, 228]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodeccdethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.24200000000000008:
# Applied shift: 0.762531895469363
# Decoded bit-string:
# Estimated phase: 0.7604531018347114, phase with normalization: 2.3890338781235
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.24300000000000008:
# Applied shift: 0.8804023663335551
# Decoded bit-string:
# Estimated phase: 0.8785690659651131, phase with normalization: 2.7601061233072457
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.24400000000000008:
# Applied shift: -0.32930316304963353
# Decoded bit-string:
# Estimated phase: -0.3369866402273396, phase with normalization: 5.224510553883469
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.24500000000000008:
# Applied shift: 1.2995129726353174
# Decoded bit-string:
# Estimated phase: 1.3070082419959048, phase with normalization: 4.1060874912356455
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.24600000000000008:
# Applied shift: -1.6079905600737319
# Decoded bit-string:
# Estimated phase: -1.6125412879423129, phase with normalization: 1.2172374433697928
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.24700000000000008:
# Applied shift: 2.330236237255481
# Decoded bit-string:
# Estimated phase: 2.330162195447782, phase with normalization: 1.0372351277118295
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.24800000000000008:
# Applied shift: 2.642426065267327
# Decoded bit-string:
# Estimated phase: -3.636790960745369, phase with normalization: 1.1410548494397554
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.24900000000000008:
# Applied shift: 0.3546556065716812
# Decoded bit-string:
# Estimated phase: 0.35729172487687144, phase with normalization: 1.122465058061605
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2500000000000001:
# Applied shift: 2.3810413724257242
# Decoded bit-string:
# Estimated phase: -3.90226690711602, phase with normalization: 0.30703756661692017
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2510000000000001:
# Applied shift: -2.237467518281774
# Decoded bit-string:
# Estimated phase: -2.231026481334681, phase with normalization: 5.557394210633853
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2520000000000001:
# Applied shift: 0.8538423107928604
# Decoded bit-string:
# Estimated phase: 0.8573741087155611, phase with normalization: 2.6935202013189032
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2530000000000001:
# Applied shift: 0.9996470321824289
# Decoded bit-string:
# Estimated phase: 1.0038284765120444, phase with normalization: 3.153620167274473
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2540000000000001:
# Applied shift: -2.8517571420598724
# Decoded bit-string:
# Estimated phase: -2.843116128909309, phase with normalization: 3.6344578704750354
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2550000000000001:
# Applied shift: 2.808633578301004
# Decoded bit-string:
# Estimated phase: -3.479424569323514, phase with normalization: 1.6354359486525911
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2560000000000001:
# Applied shift: -1.4664248962092084
# Decoded bit-string:
# Estimated phase: -1.4673017288243675, phase with normalization: 1.6735209753053506
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2570000000000001:
# Applied shift: 0.8274637788267409
# Decoded bit-string:
# Estimated phase: 0.8269502354568816, phase with normalization: 2.597940784595689
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2580000000000001:
# Applied shift: 1.1931240998498984
# Decoded bit-string:
# Estimated phase: 1.1960017475287632, phase with normalization: 3.757350303716917
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2590000000000001:
# Applied shift: 1.578526113523026
# Decoded bit-string:
# Estimated phase: 1.5790228456135678, phase with normalization: 4.9606465716300345
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2600000000000001:
# Applied shift: 2.6002279375044344
# Decoded bit-string:
# Estimated phase: -3.6857338285442345, phase with normalization: 0.9872962955172233
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2610000000000001:
# Applied shift: 0.80084246263041
# Decoded bit-string:
# Estimated phase: 0.8002332851767271, phase with normalization: 2.5140070098692315
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2620000000000001:
# Applied shift: -2.2123804320653875
# Decoded bit-string:
# Estimated phase: -2.21952628438676, phase with normalization: 5.593523144880277
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2630000000000001:
# Applied shift: -0.8103386708503817
# Decoded bit-string:
# Estimated phase: -0.8097768500272271, phase with normalization: 3.739196304086966
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2640000000000001:
# Applied shift: -0.7081039457556022
# Decoded bit-string:
# Estimated phase: -0.7047440152606104, phase with normalization: 4.06916668617548
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2650000000000001:
# Applied shift: -1.4132027472601778
# Decoded bit-string:
# Estimated phase: -1.419913792392265, phase with normalization: 1.8223945682692242
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2660000000000001:
# Applied shift: -1.350737730306274
# Decoded bit-string:
# Estimated phase: -1.3548265169479823, phase with normalization: 2.026872274647158
# Number of differences (in bits from the original string): 1 -> [223]
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodebodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2670000000000001:
# Applied shift: 1.9011154161584323
# Decoded bit-string:
# Estimated phase: 1.9018120581122142, phase with normalization: 5.974718790273817
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.2680000000000001:
# Applied shift: 1.5090044163595036
# Decoded bit-string:
# Estimated phase: 1.5089681502113779, phase with normalization: 4.7405632552050445
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.26900000000000013:
# Applied shift: -2.831508424150986
# Decoded bit-string:
# Estimated phase: -2.828048137423132, phase with normalization: 3.6817953618323638
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.27000000000000013:
# Applied shift: -2.555221608784977
# Decoded bit-string:
# Estimated phase: -2.5561877403710187, phase with normalization: 4.535869988013287
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.27100000000000013:
# Applied shift: 2.383384192246071
# Decoded bit-string:
# Estimated phase: -3.8945418442839403, phase with normalization: 0.33130656725870145
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.27200000000000013:
# Applied shift: 2.718517731262282
# Decoded bit-string:
# Estimated phase: -3.5575159990519873, phase with normalization: 1.3901044867092955
# Number of differences (in bits from the original string): 0 -> []
# Decoded ASCII string:
# hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard
# For a 128-QAM encoder with distance d = 0.27300000000000013:
# ERROR: You have some points that are outside the constrained square. Try to lower the distance or reduce the size of the constellation.
# --------------------
# The ideal distances for a 128-QAM are: [0.155, 0.156, 0.159, 0.16, 0.167, 0.168, 0.17200000000000001, 0.17500000000000002, 0.17600000000000002, 0.18200000000000002, 0.18500000000000003, 0.18600000000000003, 0.18800000000000003, 0.19000000000000003, 0.19100000000000003, 0.19200000000000003, 0.19300000000000003, 0.19500000000000003, 0.19600000000000004, 0.19800000000000004, 0.20000000000000004, 0.20100000000000004, 0.20300000000000004, 0.20400000000000004, 0.20600000000000004, 0.20700000000000005, 0.20800000000000005, 0.20900000000000005, 0.21000000000000005, 0.21100000000000005, 0.21300000000000005, 0.21400000000000005, 0.21500000000000005, 0.21700000000000005, 0.21800000000000005, 0.22100000000000006, 0.22200000000000006, 0.22300000000000006, 0.22400000000000006, 0.22500000000000006, 0.22600000000000006, 0.22700000000000006, 0.22800000000000006, 0.22900000000000006, 0.23000000000000007, 0.23100000000000007, 0.23200000000000007, 0.23300000000000007, 0.23400000000000007, 0.23500000000000007, 0.23600000000000007, 0.23700000000000007, 0.23800000000000007, 0.23900000000000007, 0.24000000000000007, 0.24200000000000008, 0.24300000000000008, 0.24400000000000008, 0.24500000000000008, 0.24600000000000008, 0.24700000000000008, 0.24800000000000008, 0.24900000000000008, 0.2500000000000001, 0.2510000000000001, 0.2520000000000001, 0.2530000000000001, 0.2540000000000001, 0.2550000000000001, 0.2560000000000001, 0.2570000000000001, 0.2580000000000001, 0.2590000000000001, 0.2600000000000001, 0.2610000000000001, 0.2620000000000001, 0.2630000000000001, 0.2640000000000001, 0.2650000000000001, 0.2670000000000001, 0.2680000000000001, 0.26900000000000013, 0.27000000000000013, 0.27100000000000013, 0.27200000000000013]
# The ideal distances for a 8192-QAM are: []
# The ideal distances for a 16384-QAM are: []
# The ideal distances for a 2097152-QAM are: []
# The ideal distances for a 67108864-QAM are: []
# The ideal distances for a 549755813888-QAM are: []
# The ideal distances for a 4398046511104-QAM are: []
# The ideal distances for a 302231454903657293676544-QAM are: []
# The ideal distances for a 2475880078570760549798248448-QAM are: []
# The ideal distances for a 6129982163463555433433388108601236734474956488734408704-QAM are: []
# The ideal distances for a 15177100720513508366558296147058741458143803430094840009779784451085189728165691392-QAM are: []
# The ideal distances for a 230344386280611654799899571593522271174128492457058131614758685317726084130380178960334883128519211886075950624436269830308263222041308144077235977260296389382897664-QAM are: []

# %% [markdown]
# ## Using the provided server

# %% [markdown]
# ### Functions to use the provided server

# %%
def serialize_complex(complex_vector,file_name):
    complex_vector = complex_vector.reshape(-1)
    np.savetxt(file_name,np.concatenate([np.real(complex_vector),
    np.imag(complex_vector)]))

def deserialize_complex(file_name):
    tx_data = np.loadtxt(file_name)
    N_sample = tx_data.size
    N_sample = N_sample//2
    tx_data = tx_data[0:N_sample] + 1j*tx_data[N_sample:(2*N_sample)]
    return tx_data

# %% [markdown]
# ### Setting up the hyper-parameters, constellation & alphabet

# %%
# str_to_process = "hellohowareyoutodayimtryingtodecodethestringliketheonegivenattheexambutitshard" # 78-chars ASCII string
encoder = m_qam_encoder

original_bitstr = ascii_str_to_binary(str_to_process)
codeword_size = 8 # TODO: FIND BEST PARAMETER VALUE
d = 0.191 # TODO: FIND BEST PARAMETER VALUE
n_dummy_symbols = 22 # TODO: FIND BEST PARAMETER VALUE
max_energy = 3/2

# For a m-QAM constellation & associated 256-symbols alphabet
constellation = m_qam(2**codeword_size, d)
alphabet = get_alphabet_from_codeword_length(codeword_size)

# %% [markdown]
# ### Encoding the string and serializing it

# %%
encoded_str = encode_string(str_to_process, constellation=constellation, alphabet=alphabet, n_dummy_symbols=n_dummy_symbols, energy_per_symbol=1, encoder=encoder)
serialize_complex(encoded_str, "input.txt")

# %% [markdown]
# ### De-serializing the file and decoding the string

# %%
noisy_result = deserialize_complex("output.txt")
decoded_bitstr = decode_str(noisy_result, n_dummy_symbols=n_dummy_symbols, alphabet=alphabet, constellation=constellation)
print(get_diff_positions(original_bitstr, decoded_bitstr))
print(binary_to_ascii_str(decoded_bitstr))
